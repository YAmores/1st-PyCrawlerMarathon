# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
r.text = original text
json.loads(r.text) = text sorted

# %%
'''
Your Code
'''

import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10965937054","type":"PullRequestEvent","actor":{"id":692171,"login":"HackToHell","display_login":"HackToHell","gravatar_id":"","url":"https://api.github.com/users/HackToHell","avatar_url":"https://avatars.githubusercontent.com/u/692171?"},"repo":{"id":118696902,"name":"rapyuta-robotics/io_tutorials","url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials"},"payload":{"action":"opened","number":22,"pull_request":{"url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22","id":346524026,"node_id":"MDExOlB1bGxSZXF1ZXN0MzQ2NTI0MDI2","html_url":"https://github.com/rapyuta-robotics/io_tutorials/pull/22","diff_url":"https://github.com/rapyuta-robotics/io_tutorials/pull/22.diff","patch_url":"https://github.com/rapyuta-robotics/io_tutorials/pull/22.patch","issue_url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/22","number":22,"state":"open","locked":false,"title":"Revert \\"Yu gazebo sim examples\\"","user":{"login":"HackToHell","id":692171,"node_id":"MDQ6VXNlcjY5MjE3MQ==","avatar_url":"https://avatars2.githubusercontent.com/u/692171?v=4","gravatar_id":"","url":"https://api.github.com/users/HackToHell","html_url":"https://github.com/HackToHell","followers_url":"https://api.github.com/users/HackToHell/followers","following_url":"https://api.github.com/users/HackToHell/following{/other_user}","gists_url":"https://api.github.com/users/HackToHell/gists{/gist_id}","starred_url":"https://api.github.com/users/HackToHell/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/HackToHell/subscriptions","organizations_url":"https://api.github.com/users/HackToHell/orgs","repos_url":"https://api.github.com/users/HackToHell/repos","events_url":"https://api.github.com/users/HackToHell/events{/privacy}","received_events_url":"https://api.github.com/users/HackToHell/received_events","type":"User","site_admin":false},"body":"Reverts rapyuta-robotics/io_tutorials#19","created_at":"2019-11-28T05:10:04Z","updated_at":"2019-11-28T05:10:04Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22/commits","review_comments_url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22/comments","review_comment_url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/comments{/number}","comments_url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/22/comments","statuses_url":"https://api.github.com/repos/rapyuta-robotics/io_tutorials/statuses/4a993cdccedd5eef3cb0b8081713c0c71a584064","head":{"label":"rapyuta-robotics:revert-19-yu_gazebo_sim_examples","ref":"revert-19-yu_gazebo_sim_examples","sha":"4a993cdccedd5eef3cb0b8081713c0c71a584064","user":{"login":"rapyuta-robotics","id":5561762,"node_id":"MDEyOk9yZ2FuaXphdGlvbjU1NjE3NjI=","avatar_url":"https://avatars2.githubusercontent.com/u/5561762?v=4","gravatar_id":"","url":"https://api.github.com/users/rapyuta-robotics","html_url":"https://github.com/rapyuta-robotics","followers_url":"https://api.github.com/users/rapyuta-robotics/followers","following_url":"https://api.github.com/users/rapyuta-robotics/following{/other_user}","gists_url":"https://api.github.com/users/rapyuta-robotics/gists{/gist_id}","starred_url":"https://api.github.com/users/rapyuta-robotics/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/rapyuta-robotics/subscriptions","organizations_url":"https://api.github.com/users/rapyuta-robotics/orgs","repos_url":"https://api.github.com/users/rapyuta-robotics/repos","events_url":"https://api.github.com/users/rapyuta-robotics/events{/privacy}","received_events_url":"https://api.github.com/users/rapyuta-robotics/received_events","type":"Organization","site_admin":false},"repo":{"id":118696902,"node_id":"MDEwOlJlcG9zaXRvcnkxMTg2OTY5MDI=","name":"io_tutorials","full_name":"rap ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10965937054',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 692171,
#    'login': 'HackToHell',
#    'display_login': 'HackToHell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HackToHell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/692171?'},
#   'repo': {'id': 118696902,
#    'name': 'rapyuta-robotics/io_tutorials',
#    'url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials'},
#   'payload': {'action': 'opened',
#    'number': 22,
#    'pull_request': {'url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22',
#     'id': 346524026,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NTI0MDI2',
#     'html_url': 'https://github.com/rapyuta-robotics/io_tutorials/pull/22',
#     'diff_url': 'https://github.com/rapyuta-robotics/io_tutorials/pull/22.diff',
#     'patch_url': 'https://github.com/rapyuta-robotics/io_tutorials/pull/22.patch',
#     'issue_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/22',
#     'number': 22,
#     'state': 'open',
#     'locked': False,
#     'title': 'Revert "Yu gazebo sim examples"',
#     'user': {'login': 'HackToHell',
#      'id': 692171,
#      'node_id': 'MDQ6VXNlcjY5MjE3MQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/692171?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/HackToHell',
#      'html_url': 'https://github.com/HackToHell',
#      'followers_url': 'https://api.github.com/users/HackToHell/followers',
#      'following_url': 'https://api.github.com/users/HackToHell/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/HackToHell/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/HackToHell/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/HackToHell/subscriptions',
#      'organizations_url': 'https://api.github.com/users/HackToHell/orgs',
#      'repos_url': 'https://api.github.com/users/HackToHell/repos',
#      'events_url': 'https://api.github.com/users/HackToHell/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/HackToHell/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Reverts rapyuta-robotics/io_tutorials#19',
#     'created_at': '2019-11-28T05:10:04Z',
#     'updated_at': '2019-11-28T05:10:04Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22/commits',
#     'review_comments_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22/comments',
#     'review_comment_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/22/comments',
#     'statuses_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/statuses/4a993cdccedd5eef3cb0b8081713c0c71a584064',
#     'head': {'label': 'rapyuta-robotics:revert-19-yu_gazebo_sim_examples',
#      'ref': 'revert-19-yu_gazebo_sim_examples',
#      'sha': '4a993cdccedd5eef3cb0b8081713c0c71a584064',
#      'user': {'login': 'rapyuta-robotics',
#       'id': 5561762,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NjE3NjI=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/5561762?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rapyuta-robotics',
#       'html_url': 'https://github.com/rapyuta-robotics',
#       'followers_url': 'https://api.github.com/users/rapyuta-robotics/followers',
#       'following_url': 'https://api.github.com/users/rapyuta-robotics/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rapyuta-robotics/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rapyuta-robotics/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rapyuta-robotics/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rapyuta-robotics/orgs',
#       'repos_url': 'https://api.github.com/users/rapyuta-robotics/repos',
#       'events_url': 'https://api.github.com/users/rapyuta-robotics/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rapyuta-robotics/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 118696902,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTg2OTY5MDI=',
#       'name': 'io_tutorials',
#       'full_name': 'rapyuta-robotics/io_tutorials',
#       'private': False,
#       'owner': {'login': 'rapyuta-robotics',
#        'id': 5561762,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NjE3NjI=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/5561762?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rapyuta-robotics',
#        'html_url': 'https://github.com/rapyuta-robotics',
#        'followers_url': 'https://api.github.com/users/rapyuta-robotics/followers',
#        'following_url': 'https://api.github.com/users/rapyuta-robotics/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rapyuta-robotics/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rapyuta-robotics/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rapyuta-robotics/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rapyuta-robotics/orgs',
#        'repos_url': 'https://api.github.com/users/rapyuta-robotics/repos',
#        'events_url': 'https://api.github.com/users/rapyuta-robotics/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rapyuta-robotics/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rapyuta-robotics/io_tutorials',
#       'description': 'Assorted tutorial code for rapyuta.io',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials',
#       'forks_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/forks',
#       'keys_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/teams',
#       'hooks_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/events',
#       'assignees_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/tags',
#       'blobs_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/languages',
#       'stargazers_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/subscription',
#       'commits_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/merges',
#       'archive_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/downloads',
#       'issues_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/deployments',
#       'created_at': '2018-01-24T02:00:39Z',
#       'updated_at': '2019-11-18T12:23:09Z',
#       'pushed_at': '2019-11-28T05:09:56Z',
#       'git_url': 'git://github.com/rapyuta-robotics/io_tutorials.git',
#       'ssh_url': 'git@github.com:rapyuta-robotics/io_tutorials.git',
#       'clone_url': 'https://github.com/rapyuta-robotics/io_tutorials.git',
#       'svn_url': 'https://github.com/rapyuta-robotics/io_tutorials',
#       'homepage': None,
#       'size': 1374,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'CMake',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 14,
#       'open_issues': 4,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'rapyuta-robotics:master',
#      'ref': 'master',
#      'sha': 'dfa564087f9aad6a5ee35bda86beb7a075c8c1c8',
#      'user': {'login': 'rapyuta-robotics',
#       'id': 5561762,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NjE3NjI=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/5561762?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rapyuta-robotics',
#       'html_url': 'https://github.com/rapyuta-robotics',
#       'followers_url': 'https://api.github.com/users/rapyuta-robotics/followers',
#       'following_url': 'https://api.github.com/users/rapyuta-robotics/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rapyuta-robotics/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rapyuta-robotics/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rapyuta-robotics/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rapyuta-robotics/orgs',
#       'repos_url': 'https://api.github.com/users/rapyuta-robotics/repos',
#       'events_url': 'https://api.github.com/users/rapyuta-robotics/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rapyuta-robotics/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 118696902,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTg2OTY5MDI=',
#       'name': 'io_tutorials',
#       'full_name': 'rapyuta-robotics/io_tutorials',
#       'private': False,
#       'owner': {'login': 'rapyuta-robotics',
#        'id': 5561762,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NjE3NjI=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/5561762?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rapyuta-robotics',
#        'html_url': 'https://github.com/rapyuta-robotics',
#        'followers_url': 'https://api.github.com/users/rapyuta-robotics/followers',
#        'following_url': 'https://api.github.com/users/rapyuta-robotics/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rapyuta-robotics/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rapyuta-robotics/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rapyuta-robotics/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rapyuta-robotics/orgs',
#        'repos_url': 'https://api.github.com/users/rapyuta-robotics/repos',
#        'events_url': 'https://api.github.com/users/rapyuta-robotics/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rapyuta-robotics/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rapyuta-robotics/io_tutorials',
#       'description': 'Assorted tutorial code for rapyuta.io',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials',
#       'forks_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/forks',
#       'keys_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/teams',
#       'hooks_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/events',
#       'assignees_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/tags',
#       'blobs_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/languages',
#       'stargazers_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/subscription',
#       'commits_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/merges',
#       'archive_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/downloads',
#       'issues_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/deployments',
#       'created_at': '2018-01-24T02:00:39Z',
#       'updated_at': '2019-11-18T12:23:09Z',
#       'pushed_at': '2019-11-28T05:09:56Z',
#       'git_url': 'git://github.com/rapyuta-robotics/io_tutorials.git',
#       'ssh_url': 'git@github.com:rapyuta-robotics/io_tutorials.git',
#       'clone_url': 'https://github.com/rapyuta-robotics/io_tutorials.git',
#       'svn_url': 'https://github.com/rapyuta-robotics/io_tutorials',
#       'homepage': None,
#       'size': 1374,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'CMake',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 14,
#       'open_issues': 4,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22'},
#      'html': {'href': 'https://github.com/rapyuta-robotics/io_tutorials/pull/22'},
#      'issue': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/22'},
#      'comments': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/issues/22/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/pulls/22/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/rapyuta-robotics/io_tutorials/statuses/4a993cdccedd5eef3cb0b8081713c0c71a584064'}},
#     'author_association': 'MEMBER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 1238,
#     'changed_files': 27}},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z',
#   'org': {'id': 5561762,
#    'login': 'rapyuta-robotics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rapyuta-robotics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5561762?'}},
#  {'id': '10965937051',
#   'type': 'WatchEvent',
#   'actor': {'id': 3440848,
#    'login': 'snydercoder',
#    'display_login': 'snydercoder',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snydercoder',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3440848?'},
#   'repo': {'id': 54173593,
#    'name': 'storybookjs/storybook',
#    'url': 'https://api.github.com/repos/storybookjs/storybook'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z',
#   'org': {'id': 22632046,
#    'login': 'storybookjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/storybookjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22632046?'}},
#  {'id': '10965937041',
#   'type': 'PushEvent',
#   'actor': {'id': 50677325,
#    'login': 'aradaha',
#    'display_login': 'aradaha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aradaha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50677325?'},
#   'repo': {'id': 188348731,
#    'name': 'aradaha/introduction-to-derivatives-lab-ds-apply-000',
#    'url': 'https://api.github.com/repos/aradaha/introduction-to-derivatives-lab-ds-apply-000'},
#   'payload': {'push_id': 4330386165,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '07e93282a60d2946438e03f06177905a6e8714fa',
#    'before': 'badaad3113e1d8c89f1ea639bb596d94036f0ccb',
#    'commits': [{'sha': '07e93282a60d2946438e03f06177905a6e8714fa',
#      'author': {'email': 'reubenhough@gmail.com', 'name': 'REUBEN HOUGH'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aradaha/introduction-to-derivatives-lab-ds-apply-000/commits/07e93282a60d2946438e03f06177905a6e8714fa'}]},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z'},
#  {'id': '10965937044',
#   'type': 'CreateEvent',
#   'actor': {'id': 23040076,
#    'login': 'greenkeeper[bot]',
#    'display_login': 'greenkeeper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greenkeeper[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23040076?'},
#   'repo': {'id': 171140653,
#    'name': 'orbit-model/main',
#    'url': 'https://api.github.com/repos/orbit-model/main'},
#   'payload': {'ref': 'greenkeeper/ts-node-8.5.3',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': '[WIP] A model based abstrction layer for orbit.js',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z',
#   'org': {'id': 46619005,
#    'login': 'orbit-model',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/orbit-model',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46619005?'}},
#  {'id': '10965937039',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23040076,
#    'login': 'greenkeeper[bot]',
#    'display_login': 'greenkeeper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greenkeeper[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23040076?'},
#   'repo': {'id': 158005229,
#    'name': 'mCzolko/nest-test',
#    'url': 'https://api.github.com/repos/mCzolko/nest-test'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/mCzolko/nest-test/issues/28',
#     'repository_url': 'https://api.github.com/repos/mCzolko/nest-test',
#     'labels_url': 'https://api.github.com/repos/mCzolko/nest-test/issues/28/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mCzolko/nest-test/issues/28/comments',
#     'events_url': 'https://api.github.com/repos/mCzolko/nest-test/issues/28/events',
#     'html_url': 'https://github.com/mCzolko/nest-test/pull/28',
#     'id': 418135340,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjU4OTc4MDU3',
#     'number': 28,
#     'title': 'Update ts-node to the latest version 🚀',
#     'user': {'login': 'greenkeeper[bot]',
#      'id': 23040076,
#      'node_id': 'MDM6Qm90MjMwNDAwNzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/505?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/greenkeeper%5Bbot%5D',
#      'html_url': 'https://github.com/apps/greenkeeper',
#      'followers_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1131171719,
#       'node_id': 'MDU6TGFiZWwxMTMxMTcxNzE5',
#       'url': 'https://api.github.com/repos/mCzolko/nest-test/labels/greenkeeper',
#       'name': 'greenkeeper',
#       'color': '00c775',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2019-03-07T05:26:24Z',
#     'updated_at': '2019-11-28T05:10:04Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/mCzolko/nest-test/pulls/28',
#      'html_url': 'https://github.com/mCzolko/nest-test/pull/28',
#      'diff_url': 'https://github.com/mCzolko/nest-test/pull/28.diff',
#      'patch_url': 'https://github.com/mCzolko/nest-test/pull/28.patch'},
#     'body': '\n## The devDependency [ts-node](https://github.com/TypeStrong/ts-node) was updated from `7.0.1` to `8.0.3`.\nThis version is **not covered** by your **current version range**.\n\nIf you don’t accept this pull request, your project will work just like it did before. However, you might be missing out on a bunch of new features, fixes and/or performance improvements from the dependency update.\n\n---\n\n<details>\n<summary>Release Notes for Relative TypeScript</summary>\n\n<p><strong>Added</strong></p>\n<ul>\n<li>Fall back on resolving relative TypeScript packages (normal resolution is from working directory, these two things can be the same in the case of locally installed packages)</li>\n</ul>\n</details>\n\n<details>\n<summary>Commits</summary>\n<p>The new version differs by 36 commits.</p>\n<ul>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/8706c31430cc23862f2043b43fba7a3c3ca4b2c6"><code>8706c31</code></a> <code>8.0.3</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/d065dd2b9f14a62d3752ce9d0dd04dbf2b6c0c99"><code>d065dd2</code></a> <code>Update README note about relative installations</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/655c43b77fdc9784caac0bc3120455afe5e0cb8d"><code>655c43b</code></a> <code>Fallback on resolving TypeScript relatively (#793)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/c2ecc7d20138b1d22a3a4c8dc4b52db4bd43e005"><code>c2ecc7d</code></a> <code>Add note about local TypeScript to README (#789)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/74147523da8853a41b70bf04578125e2d6f84731"><code>7414752</code></a> <code>Update README with triple-slash directive example (#776)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/efaf67af47dfd80f61cb8ec526dda8c11ed5461b"><code>efaf67a</code></a> <code>Add VS Code env note to README (#738)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/2609663bf3a5b14d76c0dfe989ceba67e68d5efa"><code>2609663</code></a> <code>Avoid incrementing memory cache unnecessarily</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/b4bdb08e561f7bca802f04e74e30fd9e29b9b7de"><code>b4bdb08</code></a> <code>Specify sensitive file names for document registry</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/c21569372e0d8ba79c059771929d18568a910c77"><code>c215693</code></a> <code>Utilize TypeScript <code>sys</code> better for service host</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/062254fd95f5fd43c4dfcace01d2b64b417a2e7b"><code>062254f</code></a> <code>Conditionally enable <code>.[tj]sx</code> extensions</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/7f5284cef27e428f4e8e111fbaa004ab72d9d867"><code>7f5284c</code></a> <code>8.0.2</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/e009d792c52b56fe5ba8f5cf8965dfb03916b3dd"><code>e009d79</code></a> <code>Correct <code>fixConfig</code> include files</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/7213c0f158dbd94bf5ae345199e8636bbf7e480c"><code>7213c0f</code></a> <code>Use latest <code>typescript</code> for development</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/c8ddd66353e2fc7aac8c8e0790e71c25c58467c3"><code>c8ddd66</code></a> <code>Remove obsolete cache options in README (#767)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/544851ee58af539908c682c547e05508e3dfb731"><code>544851e</code></a> <code>Remove globally installed <code>typescript</code> from README</code></li>\n</ul>\n<p>There are 36 commits in total.</p>\n<p>See the <a href="https://urls.greenkeeper.io/TypeStrong/ts-node/compare/ad6183a1b99df4f535903e7b51ce99571221c95b...8706c31430cc23862f2043b43fba7a3c3ca4b2c6">full d ...
#    'comment': {'url': 'https://api.github.com/repos/mCzolko/nest-test/issues/comments/559344103',
#     'html_url': 'https://github.com/mCzolko/nest-test/pull/28#issuecomment-559344103',
#     'issue_url': 'https://api.github.com/repos/mCzolko/nest-test/issues/28',
#     'id': 559344103,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM0NDEwMw==',
#     'user': {'login': 'greenkeeper[bot]',
#      'id': 23040076,
#      'node_id': 'MDM6Qm90MjMwNDAwNzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/505?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/greenkeeper%5Bbot%5D',
#      'html_url': 'https://github.com/apps/greenkeeper',
#      'followers_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2019-11-28T05:10:04Z',
#     'updated_at': '2019-11-28T05:10:04Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '- The `devDependency` [ts-node](https://github.com/TypeStrong/ts-node) was updated from `7.0.1` to `8.5.3`.\n\n[Update to this version instead 🚀](https://github.com/mCzolko/nest-test/compare/master...mCzolko:greenkeeper%2Fts-node-8.5.3)'}},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z'},
#  {'id': '10965937034',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23040076,
#    'login': 'greenkeeper[bot]',
#    'display_login': 'greenkeeper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greenkeeper[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23040076?'},
#   'repo': {'id': 161089223,
#    'name': 'hisco/config-process',
#    'url': 'https://api.github.com/repos/hisco/config-process'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/hisco/config-process/issues/4',
#     'repository_url': 'https://api.github.com/repos/hisco/config-process',
#     'labels_url': 'https://api.github.com/repos/hisco/config-process/issues/4/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/hisco/config-process/issues/4/comments',
#     'events_url': 'https://api.github.com/repos/hisco/config-process/issues/4/events',
#     'html_url': 'https://github.com/hisco/config-process/pull/4',
#     'id': 418135836,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjU4OTc4NDUy',
#     'number': 4,
#     'title': 'Update ts-node to the latest version 🚀',
#     'user': {'login': 'greenkeeper[bot]',
#      'id': 23040076,
#      'node_id': 'MDM6Qm90MjMwNDAwNzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/505?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/greenkeeper%5Bbot%5D',
#      'html_url': 'https://github.com/apps/greenkeeper',
#      'followers_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1157117220,
#       'node_id': 'MDU6TGFiZWwxMTU3MTE3MjIw',
#       'url': 'https://api.github.com/repos/hisco/config-process/labels/greenkeeper',
#       'name': 'greenkeeper',
#       'color': '00c775',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 9,
#     'created_at': '2019-03-07T05:28:46Z',
#     'updated_at': '2019-11-28T05:10:04Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/hisco/config-process/pulls/4',
#      'html_url': 'https://github.com/hisco/config-process/pull/4',
#      'diff_url': 'https://github.com/hisco/config-process/pull/4.diff',
#      'patch_url': 'https://github.com/hisco/config-process/pull/4.patch'},
#     'body': '\n## The devDependency [ts-node](https://github.com/TypeStrong/ts-node) was updated from `7.0.1` to `8.0.3`.\nThis version is **not covered** by your **current version range**.\n\nIf you don’t accept this pull request, your project will work just like it did before. However, you might be missing out on a bunch of new features, fixes and/or performance improvements from the dependency update.\n\n---\n\n<details>\n<summary>Release Notes for Relative TypeScript</summary>\n\n<p><strong>Added</strong></p>\n<ul>\n<li>Fall back on resolving relative TypeScript packages (normal resolution is from working directory, these two things can be the same in the case of locally installed packages)</li>\n</ul>\n</details>\n\n<details>\n<summary>Commits</summary>\n<p>The new version differs by 36 commits.</p>\n<ul>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/8706c31430cc23862f2043b43fba7a3c3ca4b2c6"><code>8706c31</code></a> <code>8.0.3</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/d065dd2b9f14a62d3752ce9d0dd04dbf2b6c0c99"><code>d065dd2</code></a> <code>Update README note about relative installations</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/655c43b77fdc9784caac0bc3120455afe5e0cb8d"><code>655c43b</code></a> <code>Fallback on resolving TypeScript relatively (#793)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/c2ecc7d20138b1d22a3a4c8dc4b52db4bd43e005"><code>c2ecc7d</code></a> <code>Add note about local TypeScript to README (#789)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/74147523da8853a41b70bf04578125e2d6f84731"><code>7414752</code></a> <code>Update README with triple-slash directive example (#776)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/efaf67af47dfd80f61cb8ec526dda8c11ed5461b"><code>efaf67a</code></a> <code>Add VS Code env note to README (#738)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/2609663bf3a5b14d76c0dfe989ceba67e68d5efa"><code>2609663</code></a> <code>Avoid incrementing memory cache unnecessarily</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/b4bdb08e561f7bca802f04e74e30fd9e29b9b7de"><code>b4bdb08</code></a> <code>Specify sensitive file names for document registry</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/c21569372e0d8ba79c059771929d18568a910c77"><code>c215693</code></a> <code>Utilize TypeScript <code>sys</code> better for service host</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/062254fd95f5fd43c4dfcace01d2b64b417a2e7b"><code>062254f</code></a> <code>Conditionally enable <code>.[tj]sx</code> extensions</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/7f5284cef27e428f4e8e111fbaa004ab72d9d867"><code>7f5284c</code></a> <code>8.0.2</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/e009d792c52b56fe5ba8f5cf8965dfb03916b3dd"><code>e009d79</code></a> <code>Correct <code>fixConfig</code> include files</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/7213c0f158dbd94bf5ae345199e8636bbf7e480c"><code>7213c0f</code></a> <code>Use latest <code>typescript</code> for development</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/c8ddd66353e2fc7aac8c8e0790e71c25c58467c3"><code>c8ddd66</code></a> <code>Remove obsolete cache options in README (#767)</code></li>\n<li><a href="https://urls.greenkeeper.io/TypeStrong/ts-node/commit/544851ee58af539908c682c547e05508e3dfb731"><code>544851e</code></a> <code>Remove globally installed <code>typescript</code> from README</code></li>\n</ul>\n<p>There are 36 commits in total.</p>\n<p>See the <a href="https://urls.greenkeeper.io/TypeStrong/ts-node/compare/ad6183a1b99df4f535903e7b51ce99571221c95b...8706c31430cc23862f2043b43fba7a3c3ca4b2c6">full d ...
#    'comment': {'url': 'https://api.github.com/repos/hisco/config-process/issues/comments/559344102',
#     'html_url': 'https://github.com/hisco/config-process/pull/4#issuecomment-559344102',
#     'issue_url': 'https://api.github.com/repos/hisco/config-process/issues/4',
#     'id': 559344102,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM0NDEwMg==',
#     'user': {'login': 'greenkeeper[bot]',
#      'id': 23040076,
#      'node_id': 'MDM6Qm90MjMwNDAwNzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/505?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/greenkeeper%5Bbot%5D',
#      'html_url': 'https://github.com/apps/greenkeeper',
#      'followers_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2019-11-28T05:10:04Z',
#     'updated_at': '2019-11-28T05:10:04Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '- The `devDependency` [ts-node](https://github.com/TypeStrong/ts-node) was updated from `7.0.1` to `8.5.3`.\n\n[Update to this version instead 🚀](https://github.com/hisco/config-process/compare/master...hisco:greenkeeper%2Fts-node-8.5.3)'}},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z'},
#  {'id': '10965937031',
#   'type': 'PushEvent',
#   'actor': {'id': 10929390,
#    'login': 'melissachang',
#    'display_login': 'melissachang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/melissachang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10929390?'},
#   'repo': {'id': 219927164,
#    'name': 'verilycloud/vincentw-20191105-1-deployment',
#    'url': 'https://api.github.com/repos/verilycloud/vincentw-20191105-1-deployment'},
#   'payload': {'push_id': 4330386163,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '057910824d0cad97913b5858701c2dbe9bc75023',
#    'before': 'd4709e88b53baacb7151f13b5305ac945738d556',
#    'commits': [{'sha': '057910824d0cad97913b5858701c2dbe9bc75023',
#      'author': {'email': 'zhuzenglu@google.com', 'name': 'Zhuzeng Lu'},
#      'message': 'Create new bigquery dataset for project vincentw-20191105-1-rzdb-dev',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/verilycloud/vincentw-20191105-1-deployment/commits/057910824d0cad97913b5858701c2dbe9bc75023'}]},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z',
#   'org': {'id': 55002745,
#    'login': 'verilycloud',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/verilycloud',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55002745?'}},
#  {'id': '10965937029',
#   'type': 'PushEvent',
#   'actor': {'id': 56273317,
#    'login': 'RhXKGxbwQHmTREDU',
#    'display_login': 'RhXKGxbwQHmTREDU',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RhXKGxbwQHmTREDU',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56273317?'},
#   'repo': {'id': 213459059,
#    'name': 'RhXKGxbwQHmTREDU/test',
#    'url': 'https://api.github.com/repos/RhXKGxbwQHmTREDU/test'},
#   'payload': {'push_id': 4330386156,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6a4b8e84ced5caf88b5d1eac7f8492329670a91c',
#    'before': '0b0f16bc3c60d1dbedbf550d633a7a8c29cb0f87',
#    'commits': [{'sha': '6a4b8e84ced5caf88b5d1eac7f8492329670a91c',
#      'author': {'email': '56273317+RhXKGxbwQHmTREDU@users.noreply.github.com',
#       'name': 'RhXKGxbwQHmTREDU'},
#      'message': '85118765',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RhXKGxbwQHmTREDU/test/commits/6a4b8e84ced5caf88b5d1eac7f8492329670a91c'}]},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z'},
#  {'id': '10965937020',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46596644,
#    'name': 'Lombiq/Orchard-Facebook-Suite',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Facebook-Suite'},
#   'payload': {'push_id': 4330386152,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.2',
#    'head': '49b1ce76566f3d6e34ed362e988a15c78357f8b0',
#    'before': '49b1ce76566f3d6e34ed362e988a15c78357f8b0',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-28T05:10:04Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10965937021',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1313584,
#    'login': 'cocreature',
#    'display_login': 'cocreature',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cocreature',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1313584?'},
#   'repo': {'id': 207551600,
#    'name': 'digital-asset/ghcide',
#    'url': 'https://api.github.com/repos/digital-asset/ghcide'},
#   'payload': {'action': 'closed',
#    'number': 215,
#    'pull_request': {'url': 'https://api.github.com/repos/digital-asset/ghcide/pulls/215',
#     'id': 346501736,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NTAxNzM2',
#     'html_url': 'https://github.com/digital-asset/ghcide/pull/215',
#     'diff_url': 'https://github.com/digital-asset/ghcide/pull/215.diff',
#     'patch_url': 'https://github.com/digital-asset/ghcide/pull/215.patch',
#     'issue_url': 'https://api.github.com/repos/digital-asset/ghcide/issues/215',
#     'number': 215,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Tighten haskell-lsp* cabal bounds to match #203',
#     'user': {'login': 'blackgnezdo',
#      'id': 8768818,
#      'node_id': 'MDQ6VXNlcjg3Njg4MTg=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/8768818?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/blackgnezdo',
#      'html_url': 'https://github.com/blackgnezdo',
#      'followers_url': 'https://api.github.com/users/blackgnezdo/followers',
#      'following_url': 'https://api.github.com/users/blackgnezdo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/blackgnezdo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/blackgnezdo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/blackgnezdo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/blackgnezdo/orgs',
#      'repos_url': 'https://api.github.com/users/blackgnezdo/repos',
#      'events_url': 'https://api.github.com/users/blackgnezdo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/blackgnezdo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-11-28T03:11:58Z',
#     'updated_at': '2019-11-28T05:10:03Z',
#     'closed_at': '2019-11-28T05:10:03Z',
#     'merged_at': '2019-11-28T05:10:03Z',
#     'merge_commit_sha': '337a268d4c68ca9e1d0bce7140fae7f118191d09',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/digital-asset/ghcide/pulls/215/commits',
#     'review_comments_url': 'https://api.github.com/repos/digital-asset/ghcide/pulls/215/comments',
#     'review_comment_url': 'https://api.github.com/repos/digital-asset/ghcide/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/digital-asset/ghcide/issues/215/comments',
#     'statuses_url': 'https://api.github.com/repos/digital-asset/ghcide/statuses/8dc551d112a010a2a2744f5d42670326835e803c',
#     'head': {'label': 'blackgnezdo:master',
#      'ref': 'master',
#      'sha': '8dc551d112a010a2a2744f5d42670326835e803c',
#      'user': {'login': 'blackgnezdo',
#       'id': 8768818,
#       'node_id': 'MDQ6VXNlcjg3Njg4MTg=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/8768818?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/blackgnezdo',
#       'html_url': 'https://github.com/blackgnezdo',
#       'followers_url': 'https://api.github.com/users/blackgnezdo/followers',
#       'following_url': 'https://api.github.com/users/blackgnezdo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/blackgnezdo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/blackgnezdo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/blackgnezdo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/blackgnezdo/orgs',
#       'repos_url': 'https://api.github.com/users/blackgnezdo/repos',
#       'events_url': 'https://api.github.com/users/blackgnezdo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/blackgnezdo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224560169,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ1NjAxNjk=',
#       'name': 'ghcide',
#       'full_name': 'blackgnezdo/ghcide',
#       'private': False,
#       'owner': {'login': 'blackgnezdo',
# ...
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/3781dc5e15fe33f776d6fbe1b68af157bf1d8e3f'},
#     {'sha': 'ef7fe00210858f2e97f830b3d7c47d9b96a88146',
#      'author': {'email': 'yangbo.lu@nxp.com', 'name': 'Yangbo Lu'},
#      'message': 'mmc: sdhci-of-esdhc: fix up erratum A-008171 workaround\n\nA previous patch implemented an incomplete workaround of erratum\nA-008171. The complete workaround is as below. This patch is to\nimplement the complete workaround which uses SW tuning if HW tuning\nfails, and retries both HW/SW tuning once with reduced clock if\nworkaround fails. This is suggested by hardware team, and the patch\nhad been verified on LS1046A eSDHC + Phison 32G eMMC which could\ntrigger the erratum.\n\nWorkaround:\n/* For T1040, T2080, LS1021A, T1023 Rev 1: */\n1. Program TBPTR[TB_WNDW_END_PTR] = 3*DIV_RATIO.\n2. Program TBPTR[TB_WNDW_START_PTR] = 5*DIV_RATIO.\n3. Program the software tuning mode by setting TBCTL[TB_MODE] = 2\'h3.\n4. Set SYSCTL2[EXTN] and SYSCTL2[SAMPCLKSEL].\n5. Issue SEND_TUNING_BLK Command (CMD19 for SD, CMD21 for MMC).\n6. Wait for IRQSTAT[BRR], buffer read ready, to be set.\n7. Clear IRQSTAT[BRR].\n8. Check SYSCTL2[EXTN] to be cleared.\n9. Check SYSCTL2[SAMPCLKSEL], Sampling Clock Select. It\'s set value\n   indicate tuning procedure success, and clear indicate failure.\n   In case of tuning failure, fixed sampling scheme could be used by\n   clearing TBCTL[TB_EN].\n/* For LS1080A Rev 1, LS2088A Rev 1.0, LA1575A Rev 1.0: */\n1. Read the TBCTL[31:0] register. Write TBCTL[11:8]=4\'h8 and wait for\n   1ms.\n2. Read the TBCTL[31:0] register and rewrite again. Wait for 1ms second.\n3. Read the TBSTAT[31:0] register twice.\n3.1 Reset data lines by setting ESDHCCTL[RSTD] bit.\n3.2 Check ESDHCCTL[RSTD] bit.\n3.3 If ESDHCCTL[RSTD] is 0, go to step 3.4 else go to step 3.2.\n3.4 Write 32\'hFFFF_FFFF to IRQSTAT register.\n4. if TBSTAT[15:8]-TBSTAT[7:0] > 4*DIV_RATIO or TBSTAT[7:0]-TBSTAT[15:8]\n   > 4*DIV_RATIO , then program TBPTR[TB_WNDW_END_PTR] = 4*DIV_RATIO and\n   program TBPTR[TB_WNDW_START_PTR] = 8*DIV_RATIO.\n/* For LS1012A Rev1, LS1043A Rev 1.x, LS1046A 1.0: */\n1. Read the TBCTL[0:31] register. Write TBCTL[20:23]=4\'h8 and wait for\n   1ms.\n2. Read the TBCTL[0:31] register and rewrite again. Wait for 1ms second.\n3. Read the TBSTAT[0:31] register twice.\n3.1 Reset data lines by setting ESDHCCTL[RSTD] bit.\n3.2 Check ESDHCCTL[RSTD] bit.\n3.3 If ESDHCCTL[RSTD] is 0, go to step 3.4 else go to step 3.2.\n3.4 Write 32\'hFFFF_FFFF to IRQSTAT register.\n4. if TBSTAT[16:23]-TBSTAT[24:31] > 4*DIV_RATIO or TBSTAT[24:31]-\n   TBSTAT[16:23] > 4* DIV_RATIO , then program TBPTR[TB_WNDW_END_PTR] =\n   4*DIV_RATIO and program TBPTR[TB_WNDW_START_PTR] = 8*DIV_RATIO.\n/* For LS1080A Rev 1, LS2088A Rev 1.0, LA1575A Rev 1.0 LS1012A Rev1,\n * LS1043A Rev 1.x, LS1046A 1.0:\n */\n5. else program TBPTR[TB_WNDW_END_PTR] = 3*DIV_RATIO and program\n   TBPTR[TB_WNDW_START_PTR] = 5*DIV_RATIO.\n6. Program the software tuning mode by setting TBCTL[TB_MODE] = 2\'h3.\n7. Set SYSCTL2[EXTN], wait 1us and SYSCTL2[SAMPCLKSEL].\n8. Issue SEND_TUNING_BLK Command (CMD19 for SD, CMD21 for MMC).\n9. Wait for IRQSTAT[BRR], buffer read ready, to be set.\n10. Clear IRQSTAT[BRR].\n11. Check SYSCTL2[EXTN] to be cleared.\n12. Check SYSCTL2[SAMPCLKSEL], Sampling Clock Select. It\'s set value\n    indicate tuning procedure success, and clear indicate failure.\n    In case of tuning failure, fixed sampling scheme could be used by\n    clearing TBCTL[TB_EN].\n\nFixes: b1f378ab5334 ("mmc: sdhci-of-esdhc: add erratum A008171 support")\nSigned-off-by: Yinbo Zhu <yinbo.zhu@nxp.com>\nSigned-off-by: Yangbo Lu <yangbo.lu@nxp.com>\nAcked-by: Adrian Hunter <adrian.hunter@intel.com>\nSigned-off-by: Ulf Hansson <ulf.hansson@linaro.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/ef7fe00210858f2e97f830b3d7c47d9b96a88146'},
#     {'sha': '63f97aa15f1f6e5e100decbf3667e9b8478707d7',
#      'author': {'email': 'chaotian.jing@mediatek.com',
#       'name': 'Chaotian Jing'},
#      'message': "mmc: block: Make card_busy_detect() a bit more generic\n\nTo prepare for more users of card_busy_detect(), let's drop the struct\nrequest * as an in-parameter and convert to log the error message via\ndev_err() instead of pr_err().\n\nSigned-off-by: Chaotian Jing <chaotian.jing@mediatek.com>\nReviewed-by: Avri Altman <avri.altman@wdc.com>\nCc: stable@vger.kernel.org\nSigned-off-by: Ulf Hansson <ulf.hansson@linaro.org>",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/63f97aa15f1f6e5e100decbf3667e9b8478707d7'},
#     {'sha': 'adee9a7e9d6f1e071d0200363be34a8b3e03ddcc',
#      'author': {'email': 'chaotian.jing@mediatek.com',
#       'name': 'Chaotian Jing'},
#      'message': "mmc: block: Add CMD13 polling for MMC IOCTLS with R1B response\n\nMMC IOCTLS with R1B responses may cause the card to enter the busy state,\nwhich means it's not ready to receive a new request. To prevent new\nrequests from being sent to the card, use a CMD13 polling loop to verify\nthat the card returns to the transfer state, before completing the request.\n\nSigned-off-by: Chaotian Jing <chaotian.jing@mediatek.com>\nReviewed-by: Avri Altman <avri.altman@wdc.com>\nCc: stable@vger.kernel.org\nSigned-off-by: Ulf Hansson <ulf.hansson@linaro.org>",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/adee9a7e9d6f1e071d0200363be34a8b3e03ddcc'},
#     {'sha': 'f40b0c2713850d6b5eaad88e0ac15f96bb7f98ab',
#      'author': {'email': 'samitolvanen@google.com', 'name': 'Sami Tolvanen'},
#      'message': 'driver core: platform: use the correct callback type for bus_find_device\n\nplatform_find_device_by_driver calls bus_find_device and passes\nplatform_match as the callback function. Casting the function to a\nmismatching type trips indirect call Control-Flow Integrity (CFI) checking.\n\nThis change adds a callback function with the correct type and instead\nof casting the function, explicitly casts the second parameter to struct\ndevice_driver* as expected by platform_match.\n\nFixes: 36f3313d6bff9 ("platform: Add platform_find_device_by_driver() helper")\nSigned-off-by: Sami Tolvanen <samitolvanen@google.com>\nReviewed-by: Kees Cook <keescook@chromium.org>\nCc: stable <stable@vger.kernel.org>\nLink: https://lore.kernel.org/r/20191112214156.3430-1-samitolvanen@google.com\nSigned-off-by: Greg Kroah-Hartman <gregkh@linuxfoundation.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/f40b0c2713850d6b5eaad88e0ac15f96bb7f98ab'},
#     {'sha': 'b0dc1cfc54820f772223ba6c7ed5d3fc3851e765',
#      'author': {'email': 'jannh@google.com', 'name': 'Jann Horn'},
#      'message': 'binder: Fix race between mmap() and binder_alloc_print_pages()\n\nbinder_alloc_print_pages() iterates over\nalloc->pages[0..alloc->buffer_size-1] under alloc->mutex.\nbinder_alloc_mmap_handler() writes alloc->pages and alloc->buffer_size\nwithout holding that lock, and even writes them before the last bailout\npoint.\n\nUnfortunately we can\'t take the alloc->mutex in the ->mmap() handler\nbecause mmap_sem can be taken while alloc->mutex is held.\nSo instead, we have to locklessly check whether the binder_alloc has been\nfully initialized with binder_alloc_get_vma(), like in\nbinder_alloc_new_buf_locked().\n\nFixes: 8ef4665aa129 ("android: binder: Add page usage in binder stats")\nCc: stable@vger.kernel.org\nSigned-off-by: Jann Horn <jannh@google.com>\nAcked-by: Christian Brauner <christian.brauner@ubuntu.com>\nLink: https://lore.kernel.org/r/20191018205631.248274-1-jannh@google.com\nSigned-off-by: Greg Kroah-Hartman <gregkh@linuxfoundation.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/b0dc1cfc54820f772223ba6c7ed5d3fc3851e765'},
#     {'sha': 'b1b698a6aac893688cd37daf5f6ddd8ab2c5b358',
#      'author': {'email': 'jannh@google.com', 'name': 'Jann Horn'},
#      'message': 'binder: Prevent repeated use of ->mmap() via NULL mapping\n\nbinder_alloc_mmap_handler() attempts to detect the use of ->mmap() on a\nbinder_proc whose binder_alloc has already been initialized by checking\nwhether alloc->buffer is non-zero.\n\nBefore commit 880211667b20 ("binder: remove kernel vm_area for buffer\nspace"), alloc->buffer was a kernel mapping address, which is always\nnon-zero, but since that commit, it is a userspace mapping address.\n\nA sufficiently privileged user can map /dev/binder at NULL, tricking\nbinder_alloc_mmap_handler() into assuming that the binder_proc has not been\nmapped yet. This leads to memory unsafety.\nLuckily, no context on Android has such privileges, and on a typical Linux\ndesktop system, you need to be root to do that.\n\nFix it by using the mapping size instead of the mapping address to\ndistinguish the mapped case. A valid VMA can\'t have size zero.\n\nFixes: 880211667b20 ("binder: remove kernel vm_area for buffer space")\nCc: stable@vger.kernel.org\nSigned-off-by: Jann Horn <jannh@google.com>\nAcked-by: Christian Brauner <christian.brauner@ubuntu.com>\nLink: https://lore.kernel.org/r/20191018205631.248274-2-jannh@google.com\nSigned-off-by: Greg Kroah-Hartman <gregkh@linuxfoundation.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/b1b698a6aac893688cd37daf5f6ddd8ab2c5b358'},
#     {'sha': 'f0ed59ea993145c90bc972f3d75dc530c545b0bc',
#      'author': {'email': 'jannh@google.com', 'name': 'Jann Horn'},
#      'message': 'binder: Handle start==NULL in binder_update_page_range()\n\nThe old loop wouldn\'t stop when reaching `start` if `start==NULL`, instead\ncontinuing backwards to index -1 and crashing.\n\nLuckily you need to be highly privileged to map things at NULL, so it\'s not\na big problem.\n\nFix it by adjusting the loop so that the loop variable is always in bounds.\n\nThis patch is deliberately minimal to simplify backporting, but IMO this\nfunction could use a refactor. The jump labels in the second loop body are\nhorrible (the error gotos should be jumping to free_range instead), and\nboth loops would look nicer if they just iterated upwards through indices.\nAnd the up_read()+mmput() shouldn\'t be duplicated like that.\n\nCc: stable@vger.kernel.org\nFixes: 457b9a6f09f0 ("Staging: android: add binder driver")\nSigned-off-by: Jann Horn <jannh@google.com>\nAcked-by: Christian Brauner <christian.brauner@ubuntu.com>\nLink: https://lore.kernel.org/r/20191018205631.248274-3-jannh@google.com\nSigned-off-by: Greg Kroah-Hartman <gregkh@linuxfoundation.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/f0ed59ea993145c90bc972f3d75dc530c545b0bc'},
#     {'sha': 'f466eb82a698ad7f197f855388e9f4f64456bd7b',
#      'author': {'email': 'alexander.shishkin@linux.intel.com',
#       'name': 'Alexander Shishkin'},
#      'message': 'stm class: Lose the protocol driver when dropping its reference\n\nCommit c7fd62bc69d02 ("stm class: Introduce framing protocol drivers")\nforgot to tear down the link between an stm device and its protocol\ndriver when policy is removed. This leads to an invalid pointer reference\nif one tries to write to an stm device after the policy has been removed\nand the protocol driver module unloaded, leading to the below splat:\n\n> BUG: unable to handle page fault for address: ffffffffc0737068\n> #PF: supervisor read access in kernel mode\n> #PF: error_code(0x0000) - not-present page\n> PGD 3d780f067 P4D 3d780f067 PUD 3d7811067 PMD 492781067 PTE 0\n> Oops: 0000 [#1] SMP NOPTI\n> CPU: 1 PID: 26122 Comm: cat Not tainted 5.4.0-rc5+ #1\n> RIP: 0010:stm_output_free+0x40/0xc0 [stm_core]\n> Call Trace:\n>  stm_char_release+0x3e/0x70 [stm_core]\n>  __fput+0xc6/0x260\n>  ____fput+0xe/0x10\n>  task_work_run+0x9d/0xc0\n>  exit_to_usermode_loop+0x103/0x110\n>  do_syscall_64+0x19d/0x1e0\n>  entry_SYSCALL_64_after_hwframe+0x44/0xa9\n\nFix this by tearing down the link from an stm device to its protocol\ndriver when the policy involving that driver is removed.\n\nSigned-off-by: Alexander Shishkin <alexander.shishkin@linux.intel.com>\nFixes: c7fd62bc69d02 ("stm class: Introduce framing protocol drivers")\nReported-by: Ammy Yi <ammy.yi@intel.com>\nTested-by: Ammy Yi <ammy.yi@intel.com>\nCC: stable@vger.kernel.org # v4.20+\nLink: https://lore.kernel.org/r/20191114064201.43089-2-alexander.shishkin@linux.intel.com\nSigned-off-by: Greg Kroah-Hartman <gregkh@linuxfoundation.org>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/f466eb82a698ad7f197f855388e9f4f64456bd7b'},
#     {'sha': '4f56fa35572d0a3921e64e631580aacf5fd52671',
#      'author': {'email': 'ulf.hansson@linaro.org', 'name': 'Ulf Hansson'},
#      'message': "mmc: core: Drop check for mmc_card_is_removable() in mmc_rescan()\n\nUpfront in mmc_rescan() we use the host->rescan_entered flag, to allow\nscanning only once for non-removable cards. Therefore, it's also not\npossible that we can have a corresponding card bus attached (host->bus_ops\nis NULL), when we are scanning non-removable cards.\n\nFor this reason, let' drop the check for mmc_card_is_removable() as it's\nredundant.\n\nReviewed-by: Douglas Anderson <dianders@chromium.org>\nTested-by: Douglas Anderson <dianders@chromium.org>\nCc: stable@vger.kernel.org # v5.4+\nSigned-off-by: Ulf Hansson <ulf.hansson@linaro.org>",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/4f56fa35572d0a3921e64e631580aacf5fd52671'},
#     {'sha': '3208ae2998351a2ac1e6b9b1ef152a22fa2535c2',
#      'author': {'email': 'ulf.hansson@linaro.org', 'name': 'Ulf Hansson'},
#      'message': "mmc: core: Re-work HW reset for SDIO cards\n\nIt have turned out that it's not a good idea to unconditionally do a power\ncycle and then to re-initialize the SDIO card, as currently done through\nmmc_hw_reset() -> mmc_sdio_hw_reset(). This because there may be multiple\nSDIO func drivers probed, who also shares the same SDIO card.\n\nTo address these scenarios, one may be tempted to use a notification\nmechanism, as to allow the core to inform each of the probed func drivers,\nabout an ongoing HW reset. However, supporting such an operation from the\nfunc driver point of view, may not be entirely trivial.\n\nTherefore, let's use a more simplistic approach to solve the problem, by\ninstead forcing the card to be removed and re-detected, via scheduling a\nrescan-work. In this way, we can rely on existing infrastructure, as the\nfunc driver's ->remove() and ->probe() callbacks, becomes invoked to deal\nwith the cleanup and the re-initialization.\n\nThis solution may be considered as rather heavy, especially if a func\ndriver doesn't share its card with other func drivers. To address this,\nlet's keep the current immediate HW reset option as well, but run it only\nwhen there is one func driver probed for the card.\n\nFinally, to allow the caller of mmc_hw_reset(), to understand if the reset\nis being asynchronously managed from a scheduled work, it returns 1\n(propagated from mmc_sdio_hw_reset()). If the HW reset is executed\nsuccessfully and synchronously it returns 0, which maintains the existing\nbehaviour.\n\nReviewed-by: Douglas Anderson <dianders@chromium.org>\nTested-by: Douglas Anderson <dianders@chromium.org>\nCc: stable@vger.kernel.org # v5.4+\nSigned-off-by: Ulf Hansson <ulf.hansson@linaro.org>",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hohoxu/n5kernel/commits/3208ae2998351a2ac1e6b9b1ef152a22fa2535c2'}]},
#   'public': True,
#   'created_at': '2019-11-28T05:10:02Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'origin': '140.114.119.198, 140.114.119.198',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'json': None,
#  'origin': '140.114.119.198, 140.114.119.198',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'json': None,
#  'origin': '140.114.119.198, 140.114.119.198',
#  'url': 'https://httpbin.org/post'}
