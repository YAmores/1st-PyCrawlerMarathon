# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 利用 urllib 套件的 urlretrieve 方法下載檔案
# * 了解 Python File I/O 讀檔、寫檔的用法
# * 能用運用資源管理器 With Statement 優化寫法

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
Your Code
'''

import requests
import json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
r.text
# Out:
# '[{"id":232579336,"title":"我養到別人家的貓","excerpt":"搭給齁～先放一張可愛的貓貓，進入正題～之前有在寵物版發文，我家的阿咪會你丟我撿🤣，影片在此⬇️，直到最近他又學會了新技能，說來就來，時常在懷疑他到底是貓還是狗🤨，他也不會亂大小便，咬東西砸電視也不","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-11-27T02:15:28.197Z","updatedAt":"2019-11-27T02:18:35.377Z","commentCount":8,"likeCount":181,"withNickname":true,"tags":[],"topics":["貓","虎斑貓","領養代替購買"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"Q醬a娘🐈","department":"sindy_0413","replyTitle":null,"mediaMeta":[{"id":"7b6119ea-304c-4e75-a961-ebeae19c8c61","url":"https://i.imgur.com/9NdL9MIl.jpg","normalizedUrl":"https://i.imgur.com/9NdL9MIl.jpg","thumbnail":"https://i.imgur.com/9NdL9MIl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-11-27T02:18:35.377Z","updatedAt":"2019-11-27T02:18:35.377Z"},{"id":"7b6119ea-304c-4e75-a961-ebeae19c8c61","url":"https://i.imgur.com/9NdL9MI.jpg","normalizedUrl":"https://imgur.com/9NdL9MI","thumbnail":"https://i.imgur.com/9NdL9MIl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-11-27T02:18:35.377Z","updatedAt":"2019-11-27T02:18:35.377Z"},{"id":"bc086196-4a8b-49ed-a32b-9d87902191c9","url":"https://www.dcard.tw/v2/vivid/videos/ab97528a-7b30-4602-9375-49def3732ac5?r=1.7777777777777777","normalizedUrl":"","thumbnail":"https://vivid.dcard.tw/Public/ab97528a-7b30-4602-9375-49def3732ac5/thumbnail.jpg","type":"video/vivid","tags":["ANNOTATED_FAILED"],"createdAt":"2019-11-27T02:15:28.197Z","updatedAt":"2019-11-27T02:18:35.377Z"},{"id":"fd3b6de0-1620-46b1-abaf-4418936c5d04","url":"https://www.dcard.tw/v2/vivid/videos/59688e8d-2c5a-43a4-8912-38b21a1bb494?r=1.7777777777777777","normalizedUrl":"","thumbnail":"https://vivid.dcard.tw/Public/59688e8d-2c5a-43a4-8912-38b21a1bb494/thumbnail.jpg","type":"video/vivid","tags":["ANNOTATED_FAILED"],"createdAt":"2019-11-27T02:15:28.197Z","updatedAt":"2019-11-27T02:18:35.377Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":175},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":6}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":true,"media":[{"url":"https://i.imgur.com/9NdL9MI.jpg"},{"url":"https://vivid.dcard.tw/Public/ab97528a-7b30-4602-9375-49def3732ac5/thumbnail.jpg"},{"url":"https://vivid.dcard.tw/Public/59688e8d-2c5a-43a4-8912-38b21a1bb494/thumbnail.jpg"}],"reportReasonText":"","postAvatar":""},{"id":232579847,"title":"哪裡來的天使","excerpt":"廢話不多說 直接上圖，拜託這位朋友分享更多萌照！！！，怎麼可以這麼口愛 一大早就被融化了-。-","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-11-27T03:55:26.087Z","updatedAt":"2019-11-27T03:56:02.825Z","commentCount":2,"likeCount":146,"withNickname":false,"tags":[],"topics":["狗","天使","可愛","拜託給我多一點"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"南臺科技大學","replyTitle":null,"mediaMeta":[{"id":"86e41d0d-1e15-436e-a143-113efc4bde3c","url":"https://i.imgur.com/ffHkPwCl.jpg","normalizedUrl":"https://i.imgur.com/ffHkPwCl.jpg","thumbnail":"https://i.imgur.com/ffHkPwCl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-11-27T03:55:26.087Z","updatedAt":"2019-11-27T03:56:02.825Z"},{"id":"86e41d0d-1e15-436e-a143-113efc4bde3c","url":"https://i.imgur.com/ffHkPwC.jpg","normalizedUrl":"https://imgur.com/ffHkPwC","thumbnail":"https://i.imgur.com/ffHkPwCl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-11-27T03:55:26.087Z","updatedAt":"2019-11-27T03:56:02.825Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":146}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/ffHkPwC.jpg"}],"reportReasonText":"","postAvatar":""},{"id":232579909,"title":"有沒有人想要認養貓😢","excerpt":"嗨，沒有什麼發文經驗，所以我也不懂怎麼排版請見諒，切入重點，半年 ...

# %%
data = json.loads(response)

count = 0
for d in data:
    print(d['id'])
    count = count + 1
print('In total', count, 'responses')
# Out:
# 232579336
# 232579847
# 232579909
# 232583260
# 232584037
# 232579519
# 232581539
# 232585212
# 232579219
# 232578338
# 232579608
# 232579471
# 232582990
# 232584893
# 232583409
# 232584249
# 232582189
# 232584380
# 232581028
# 232579331
# 232582543
# 232586197
# 232583410
# 232581511
# 232579049
# 232584404
# 232584313
# 232584000
# 232583940
# 232584469
# In total 30 responses

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

'''
Your Code
'''

for d in data:
    print(d['id'], d['title'], d['createdAt'], d['commentCount'], d['likeCount'])
# Out:
# 232579336 我養到別人家的貓 2019-11-27T02:15:28.197Z 8 181
# 232579847 哪裡來的天使 2019-11-27T03:55:26.087Z 2 146
# 232579909 有沒有人想要認養貓😢 2019-11-27T04:05:54.907Z 12 119
# 232583260 最近刺蝟有點苦惱…… 2019-11-27T14:09:04.187Z 7 92
# 232584037 貓咪送養 2019-11-27T15:53:37.579Z 5 62
# 232579519 我好像養了一顆球（？ 2019-11-27T02:51:29.228Z 8 35
# 232581539 跪求原圖 2019-11-27T09:03:30.781Z 3 32
# 232585212 教不到2天就會握手的貓？！ 2019-11-27T19:05:47.181Z 13 30
# 232579219 黑貓 2019-11-27T01:46:18.916Z 3 30
# 232578338 藏起來的蛋蛋 2019-11-26T18:06:41.515Z 7 30
# 232579608 可愛ㄉ米克斯🐶 2019-11-27T03:08:52.535Z 9 29
# 232579471 #更新  尋貓啟示（拜託幫幫忙 2019-11-27T02:42:25.099Z 2 25
# 232582990 小cookie 一歲生日嘍 2019-11-27T13:29:28.841Z 2 24
# 232584893 兔子吃草a跩樣 2019-11-27T17:48:07.040Z 1 20
# 232583409 送養貓咪 2019-11-27T14:33:01.950Z 2 19
# 232584249 開箱ㄐㄅ貓貓 2019-11-27T16:20:13.198Z 1 16
# 232582189 尋貓啟示#台南永康南應大 2019-11-27T11:11:21.836Z 4 16
# 232584380 耐ㄍ⋯ 2019-11-27T16:36:38.742Z 7 15
# 232581028 蛇蛇吃飯（不喜勿入喔 2019-11-27T07:36:04.550Z 4 13
# 232579331 ［協助汪星人回家］ 2019-11-27T02:13:43.258Z 0 13
# 232582543 妳的柯基犬很可愛 2019-11-27T12:15:40.192Z 12 11
# 232586197 幼貓送養文 2019-11-28T02:52:25.651Z 2 10
# 232583410 貓咪要如何避免被自己的💩臭死？ 2019-11-27T14:33:19.704Z 2 9
# 232581511 終於知道去哪裡學來的睡姿⋯⋯ 2019-11-27T08:59:09.803Z 8 9
# 232579049 睡姿同步之雙傻組 2019-11-27T00:56:58.462Z 1 9
# 232584404 我家阿北有老人味🦜 求解 2019-11-27T16:39:41.215Z 4 7
# 232584313 求領養🙏🏼 2019-11-27T16:26:53.184Z 0 6
# 232584000 #片  男帥女俏 2019-11-27T15:48:46.456Z 1 6
# 232583940 女大十八變❓🤷🏻‍♀️ 2019-11-27T15:40:40.727Z 1 6
# 232584469 我家的貓會握手了！ 2019-11-27T16:47:38.502Z 2 5

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
#popular=false
p = pcom = plike = 0
for d in data:
    p = p + 1
    pcom = pcom + d['commentCount']
    plike = plike + d['likeCount']

#popular=false
rr = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
data1 = json.loads(rr.text)

q = qcom = qlike = 0
for d in data1:
    q = q + 1
    qcom = qcom + d['commentCount']
    qlike = qlike + d['likeCount']

print('for the popular (average comments, average likes):', 
      pcom / p, plike / p,
      'for the unpopular (average comments, average likes):',
      qcom / q, qlike / q,
      sep = '\n')
# Out:
# for the popular (average comments, average likes):
# 4.433333333333334
# 34.166666666666664
# for the unpopular (average comments, average likes):
# 2.966666666666667
# 14.633333333333333
