# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
url = "https://news.chosun.com/international/"
r = requests.get(url)
response = r.text
response
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1"/><script type="text/javascript" src="/pf/resources/js/polyfill.min.js?d=301"></script><title>국제 섹션 - 조선일보</title><link rel="canonical" href="https://www.chosun.com/international/"/><meta name="description" content="뉴스 기반의 지식네트워크를 지향하는 조선닷컴은 1995년 국내 최초로 온라인 뉴스서비스를 실시하여, 가장 빠른 국내 최고의 온라인 뉴스를 제공합니다."/><script type="text/javascript">\n    (function() {\n      /** CONFIGURATION START **/\n      var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});\n\n      _sf_async_config.uid = 66066;\n      _sf_async_config.domain = "chosun.com";\n      _sf_async_config.flickerControl = false;\n      _sf_async_config.useCanonical = true;\n      _sf_async_config.useCanonicalDomain = true;\n      _sf_async_config.sections = "국제";\n      _sf_async_config.authors = "";\n      _sf_async_config.mobileApp = false;\n      _sf_async_config.type = "section";\n      /** CONFIGURATION END **/\n      function loadChartbeat() {\n          var e = document.createElement(\'script\');\n          var n = document.getElementsByTagName(\'script\')[0];\n          e.type = \'text/javascript\';\n          e.async = true;\n          e.src = \'//static.chartbeat.com/js/chartbeat.js\';\n          n.parentNode.insertBefore(e, n);\n      }\n      loadChartbeat();\n    })();\n    </script><script type="text/javascript">(function(w,d,s,l,i){\n        w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});\n        var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';\n        j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\', \'GTM-WNX23JV\');</script><script type="application/javascript">if(!Array.prototype.includes||!(window.Object && window.Object.assign)||!window.Promise||!window.Symbol||!window.fetch){document.write(\'<script type="application/javascript" src="/pf/dist/engine/polyfill.js?d=301" defer=""><\\/script>\')}</script><script id="fusion-engine-script" type="application/javascript" src="/pf/dist/engine/react.js?d=301" defer=""></script><script id="fusion-engine-script" type="application/javascript" src="/pf/dist/components/combinations/default.js?d=301" defer=""></script><link id="fusion-template-styles" rel="stylesheet" type="text/css"/><style data-styled="ilUyeR clWyhS cQsdjy cRlqOO hlQRRh gIeir gFmqXw kHSloe kyZJpD kmbJvT hqzazl" data-styled-version="4.4.1">\n/* sc-component-id: styled__GalleryDiv-sc-1khna8c-0 */\n.ilUyeR{display:block;width:100%;overflow:hidden;margin-bottom:40px;}\n/* sc-component-id: styled__ControlsDiv-sc-1khna8c-2 */\n.clWyhS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:12px;}\n/* sc-component-id: styled__ControlContainer-sc-1khna8c-3 */\n.cQsdjy{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;line-height:1rem;width:auto;} .cQsdjy,.cQsdjy > button,.cQsdjy > span{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#191919;font-size:14px;font-weight:500;}\n/* sc-component-id: styled__ControlsButton-sc-1khna8c-4 */\n.cRlqOO{background:none;border:none;padding:0;height:auto;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .cRlqOO:hover{cursor:pointer;} .cRlqOO .sr-only{display:none;} .cRlqOO svg{height:1rem;width:1rem;} .cRlqOO > *{-webkit-flex:auto;-ms-flex:auto;flex:auto;line-height:1;}\n/* s ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
import requests
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}
r = requests.get(url,headers=headers)
response = r.text

response
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1"/><script type="text/javascript" src="/pf/resources/js/polyfill.min.js?d=301"></script><title>국제 섹션 - 조선일보</title><link rel="canonical" href="https://www.chosun.com/international/"/><meta name="description" content="뉴스 기반의 지식네트워크를 지향하는 조선닷컴은 1995년 국내 최초로 온라인 뉴스서비스를 실시하여, 가장 빠른 국내 최고의 온라인 뉴스를 제공합니다."/><script type="text/javascript">\n    (function() {\n      /** CONFIGURATION START **/\n      var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});\n\n      _sf_async_config.uid = 66066;\n      _sf_async_config.domain = "chosun.com";\n      _sf_async_config.flickerControl = false;\n      _sf_async_config.useCanonical = true;\n      _sf_async_config.useCanonicalDomain = true;\n      _sf_async_config.sections = "국제";\n      _sf_async_config.authors = "";\n      _sf_async_config.mobileApp = false;\n      _sf_async_config.type = "section";\n      /** CONFIGURATION END **/\n      function loadChartbeat() {\n          var e = document.createElement(\'script\');\n          var n = document.getElementsByTagName(\'script\')[0];\n          e.type = \'text/javascript\';\n          e.async = true;\n          e.src = \'//static.chartbeat.com/js/chartbeat.js\';\n          n.parentNode.insertBefore(e, n);\n      }\n      loadChartbeat();\n    })();\n    </script><script type="text/javascript">(function(w,d,s,l,i){\n        w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});\n        var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';\n        j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\', \'GTM-WNX23JV\');</script><script type="application/javascript">if(!Array.prototype.includes||!(window.Object && window.Object.assign)||!window.Promise||!window.Symbol||!window.fetch){document.write(\'<script type="application/javascript" src="/pf/dist/engine/polyfill.js?d=301" defer=""><\\/script>\')}</script><script id="fusion-engine-script" type="application/javascript" src="/pf/dist/engine/react.js?d=301" defer=""></script><script id="fusion-engine-script" type="application/javascript" src="/pf/dist/components/combinations/default.js?d=301" defer=""></script><link id="fusion-template-styles" rel="stylesheet" type="text/css"/><style data-styled="ilUyeR clWyhS cQsdjy cRlqOO hlQRRh gIeir gFmqXw kHSloe kyZJpD kmbJvT fpSNML hqzazl xiPmR" data-styled-version="4.4.1">\n/* sc-component-id: image-metadata__MetadataParagraph-sc-1bd80p5-0 */\n.xiPmR{font-family:ChosunGothic;font-size:14px;color:#999;margin:8px 0;line-height:1.43;} .xiPmR > *{font-family:ChosunGothic;} .xiPmR .title{color:#7F8C8D;font-weight:bold;}\n/* sc-component-id: styled__GalleryDiv-sc-1khna8c-0 */\n.ilUyeR{display:block;width:100%;overflow:hidden;margin-bottom:40px;}\n/* sc-component-id: styled__ControlsDiv-sc-1khna8c-2 */\n.clWyhS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:12px;}\n/* sc-component-id: styled__ControlContainer-sc-1khna8c-3 */\n.cQsdjy{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;line-height:1rem;width:auto;} .cQsdjy,.cQsdjy > button,.cQsdjy > span{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#191919;font-size:14px;font-weight:500;}\n/* sc-component-id: styled__ControlsButton-sc-1khna8c-4 */\n.cRlqOO{background:none;border:none;padding:0;height:auto;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-al ...
